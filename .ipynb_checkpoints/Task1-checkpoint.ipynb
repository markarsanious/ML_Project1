# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import GridSearchCV


#read data
data = pd.read_csv("sp500_27270.csv")

# %%
#Filtering data satisfying correlation >=
filtered_companies = []
correlation = data.corr()
for i in range(len(correlation)):
    if(correlation['SP500'][i]>=0.95 or correlation['SP500'][i]<=-0.95):
        filtered_companies.append(correlation['SP500'].keys().values[i])
        
filtered_data = data.filter(filtered_companies)

# %%
#print(filtered_data.shape)
Y = np.array(filtered_data['SP500'])
X = np.array(filtered_data.drop(columns=['SP500']))

#Normalizing Data
X_scaled = preprocessing.scale(X)
Y_scaled = preprocessing.scale(Y)

X_train,X_test,Y_train,Y_test = train_test_split(X_scaled,Y_scaled,test_size=0.2)

regressor = MLPRegressor(max_iter=3000)

param_grid = {'hidden_layer_sizes': [(15, 2), (10, 2)], 'activation': ['relu', 'tanh'], 'solver':['sgd', 'adam']}

clf = GridSearchCV(regressor, param_grid=param_grid, cv=3)
clf.fit(X_train,Y_train)

print(clf.best_params_)
clf.score(X_test, Y_test)
# Out:
# {'activation': 'tanh', 'hidden_layer_sizes': (15, 2), 'solver': 'adam'}
# 0.9857523174211641

# %% [markdown]
# # TASK 2

# %%
sorted_dataframe = correlation.sort_values(['SP500'], ascending=False)
sorted_dataframe = sorted_dataframe[1:]

#print(sorted_dataframe)
maximum_company = sorted_dataframe['SP500'].keys().values[0]

maximum_company_data = data[maximum_company]
#print(maximum_company_data)

#print(data_list)

X = []
Y = []

for value in range(0,len(maximum_company_data)-9):
    x_element = list(maximum_company_data[:5])
    y_element = list(maximum_company_data[5:9])
    X.append(x_element)
    Y.append(y_element)
    maximum_company_data = maximum_company_data.shift(-1)
# Out:
# [[36.8873, 37.0548, 37.8203, 38.8106], [37.0548, 37.8203, 38.8106, 39.3896], [37.8203, 38.8106, 39.3896, 39.3943], [38.8106, 39.3896, 39.3943, 39.2269], [39.3896, 39.3943, 39.2269, 39.0212], [39.3943, 39.2269, 39.0212, 38.891999999999996], [39.2269, 39.0212, 38.891999999999996, 38.8824], [39.0212, 38.891999999999996, 38.8824, 38.6241], [38.891999999999996, 38.8824, 38.6241, 38.7245], [38.8824, 38.6241, 38.7245, 38.4757], [38.6241, 38.7245, 38.4757, 38.4135], [38.7245, 38.4757, 38.4135, 38.2413], [38.4757, 38.4135, 38.2413, 38.4135], [38.4135, 38.2413, 38.4135, 38.1791], [38.2413, 38.4135, 38.1791, 38.6958], [38.4135, 38.1791, 38.6958, 38.404], [38.1791, 38.6958, 38.404, 38.9159], [38.6958, 38.404, 38.9159, 38.7963], [38.404, 38.9159, 38.7963, 38.9303], [38.9159, 38.7963, 38.9303, 39.0834], [38.7963, 38.9303, 39.0834, 39.5761], [38.9303, 39.0834, 39.5761, 40.2364], [39.0834, 39.5761, 40.2364, 40.5617], [39.5761, 40.2364, 40.5617, 40.4947], [40.2364, 40.5617, 40.4947, 40.6239], [40.5617, 40.4947, 40.6239, 40.6622], [40.4947, 40.6239, 40.6622, 40.7196], [40.6239, 40.6622, 40.7196, 40.6909], [40.6622, 40.7196, 40.6909, 40.667], [40.7196, 40.6909, 40.667, 40.6718], [40.6909, 40.667, 40.6718, 40.667], [40.667, 40.6718, 40.667, 40.6909], [40.6718, 40.667, 40.6909, 40.8296], [40.667, 40.6909, 40.8296, 40.7435], [40.6909, 40.8296, 40.7435, 40.6813], [40.8296, 40.7435, 40.6813, 41.198], [40.7435, 40.6813, 41.198, 41.5241], [40.6813, 41.198, 41.5241, 41.4714], [41.198, 41.5241, 41.4714, 40.7377], [41.5241, 41.4714, 40.7377, 40.7904], [41.4714, 40.7377, 40.7904, 40.8384], [40.7377, 40.7904, 40.8384, 41.2652], [40.7904, 40.8384, 41.2652, 41.3947], [40.8384, 41.2652, 41.3947, 41.8215], [41.2652, 41.3947, 41.8215, 41.7351], [41.3947, 41.8215, 41.7351, 42.1044], [41.8215, 41.7351, 42.1044, 42.1476], [41.7351, 42.1044, 42.1476, 42.2914], [42.1044, 42.1476, 42.2914, 42.4065], [42.1476, 42.2914, 42.4065, 42.3298], [42.2914, 42.4065, 42.3298, 42.5408], [42.4065, 42.3298, 42.5408, 42.7662], [42.3298, 42.5408, 42.7662, 42.0756], [42.5408, 42.7662, 42.0756, 42.2291], [42.7662, 42.0756, 42.2291, 41.8406], [42.0756, 42.2291, 41.8406, 42.1236], [42.2291, 41.8406, 42.1236, 42.3586], [41.8406, 42.1236, 42.3586, 42.8813], [42.1236, 42.3586, 42.8813, 42.8429], [42.3586, 42.8813, 42.8429, 42.771], [42.8813, 42.8429, 42.771, 44.3151], [42.8429, 42.771, 44.3151, 44.1425], [42.771, 44.3151, 44.1425, 44.0562], [44.3151, 44.1425, 44.0562, 44.1569], [44.1425, 44.0562, 44.1569, 43.6581], [44.0562, 44.1569, 43.6581, 43.6725], [44.1569, 43.6581, 43.6725, 42.4353], [43.6581, 43.6725, 42.4353, 41.1885], [43.6725, 42.4353, 41.1885, 40.9247], [42.4353, 41.1885, 40.9247, 41.2844], [41.1885, 40.9247, 41.2844, 41.0638], [40.9247, 41.2844, 41.0638, 41.5625], [41.2844, 41.0638, 41.5625, 41.6632], [41.0638, 41.5625, 41.6632, 40.6082], [41.5625, 41.6632, 40.6082, 40.7425], [41.6632, 40.6082, 40.7425, 40.9199], [40.6082, 40.7425, 40.9199, 41.5769], [40.7425, 40.9199, 41.5769, 41.8934], [40.9199, 41.5769, 41.8934, 41.7351], [41.5769, 41.8934, 41.7351, 42.1811], [41.8934, 41.7351, 42.1811, 42.3346], [41.7351, 42.1811, 42.3346, 42.4593], [42.1811, 42.3346, 42.4593, 42.3298], [42.3346, 42.4593, 42.3298, 42.6079], [42.4593, 42.3298, 42.6079, 42.4641], [42.3298, 42.6079, 42.4641, 42.6559], [42.6079, 42.4641, 42.6559, 42.277], [42.4641, 42.6559, 42.277, 42.6367], [42.6559, 42.277, 42.6367, 42.3586], [42.277, 42.6367, 42.3586, 41.7591], [42.6367, 42.3586, 41.7591, 42.0037], [42.3586, 41.7591, 42.0037, 42.2099], [41.7591, 42.0037, 42.2099, 42.0948], [42.0037, 42.2099, 42.0948, 43.1498], [42.2099, 42.0948, 43.1498, 42.8237], [42.0948, 43.1498, 42.8237, 43.2793], [43.1498, 42.8237, 43.2793, 43.356], [42.8237, 43.2793, 43.356, 43.4906], [43.2793, 43.356, 43.4906, 43.1782], [43.356, 43.4906, 43.1782, 43.5242], [43.4906, 43.1782, 43.5242, 43.3656], [43.1782, 43.5242, 43.3656, 43.4906], [43.5242, 43.3656, 43.4906, 43.851000000000006], [43.3656, 43.4906, 43.851000000000006, 44.0962], [43.4906, ...

# %%
#Normalizing Data
X_scaled = preprocessing.scale(X)
Y_scaled = preprocessing.scale(Y)

X_train,X_test,Y_train,Y_test = train_test_split(X_scaled,Y_scaled,test_size=0.2)

regressor = MLPRegressor(max_iter=3000)

param_grid = {'hidden_layer_sizes': [(15, 2), (10, 2)], 'activation': ['relu', 'tanh'], 'solver':['sgd', 'adam']}

clf = GridSearchCV(regressor, param_grid=param_grid, cv=3)
clf.fit(X_train,Y_train)

print(clf.best_params_)
clf.score(X_test, Y_test)
# Out:
# {'activation': 'relu', 'hidden_layer_sizes': (10, 2), 'solver': 'sgd'}
# 0.973641580409762
